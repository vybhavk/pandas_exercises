# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",delimiter='\t')

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda s: float(s[1:]))
chipo[(chipo['quantity']==1)&(chipo['item_price']>10)]['item_name'].nunique()
# Out:
# 25

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
chipo[(chipo['quantity']==1)&(chipo['item_price']>10)][['item_name','item_price']].drop_duplicates()
# Out:
#                   item_name  item_price
# 5              Chicken Bowl       10.98
# 7             Steak Burrito       11.75
# 13             Chicken Bowl       11.25
# 23          Chicken Burrito       10.98
# 39            Barbacoa Bowl       11.75
# 57           Veggie Burrito       11.25
# 62              Veggie Bowl       11.25
# 79       Chicken Soft Tacos       11.25
# 90               Steak Bowl       11.75
# 93         Carnitas Burrito       11.75
# 97            Carnitas Bowl       11.75
# 130        Barbacoa Burrito       11.75
# 147           Steak Burrito       11.48
# 163           Carnitas Bowl       11.48
# 167         Chicken Burrito       11.25
# 168   Barbacoa Crispy Tacos       11.75
# 186       Veggie Salad Bowl       11.25
# 187              Steak Bowl       11.48
# 250           Chicken Salad       10.98
# 322           Steak Burrito       11.08
# 365    Chicken Crispy Tacos       11.25
# 427      Chicken Soft Tacos       10.98
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo[(chipo['quantity']==1)&(chipo['item_price']>10)][['item_name','item_price']].drop_duplicates().sort_values('item_name',ascending=True)
# Out:
#                   item_name  item_price
# 4510          Barbacoa Bowl       11.49
# 471           Barbacoa Bowl       11.48
# 39            Barbacoa Bowl       11.75
# 130        Barbacoa Burrito       11.75
# 3276       Barbacoa Burrito       11.48
# 1648       Barbacoa Burrito       11.08
# 168   Barbacoa Crispy Tacos       11.75
# 429   Barbacoa Crispy Tacos       11.48
# 1229    Barbacoa Salad Bowl       11.89
# 988     Barbacoa Soft Tacos       11.75
# 3184    Barbacoa Soft Tacos       11.48
# 163           Carnitas Bowl       11.48
# 822           Carnitas Bowl       11.08
# 97            Carnitas Bowl       11.75
# 93         Carnitas Burrito       11.75
# 2884       Carnitas Burrito       11.08
# 1063       Carnitas Burrito       11.48
# 1008  Carnitas Crispy Tacos       11.75
# 1132    Carnitas Salad Bowl       11.89
# 1963    Carnitas Soft Tacos       11.75
# 2919           Chicken Bowl       10.58
# 5              Chicken Bowl       10.98
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
max_price = chipo['item_price'].max()
chipo[chipo['item_price']==max_price]['quantity']
# Out:
# 3598    15
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo[chipo['item_name']=='Veggie Salad Bowl'].order_id.count()
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
chipo[(chipo['item_name']=='Canned Soda')&(chipo.quantity > 1)].shape
# Out:
# (20, 5)
